# %%
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np
import seaborn as sns

# %%
rej_df = pd.read_csv("Resources/lending_club_rejected_klean_v2.csv")
rej_df
# Out:
#         Amount Requested Application Date          Loan Title  Risk_Score  \
# 0                 7000.0       2016-10-18  DEBT_CONSOLIDATION       571.0
# 1                20000.0       2018-01-14  DEBT_CONSOLIDATION       626.0
# 2                15000.0       2013-09-04  DEBT_CONSOLIDATION       673.0
# 3                10000.0       2017-02-16  DEBT_CONSOLIDATION       665.0
# 4                 2000.0       2016-03-14                HOME       601.0
# ...                  ...              ...                 ...         ...
# 224895           35000.0       2015-02-11            vacation       653.0
# 224896            4875.0       2013-12-18                  CC       680.0
# 224897           10000.0       2017-06-28  DEBT_CONSOLIDATION       655.0
# 224898           25000.0       2013-04-09                  CC       689.0
# 224899           20000.0       2016-10-26               other       685.0
#
#         Debt-To-Income Ratio State  Employment Length  Policy Code
# 0                       6.66    OK                0.5          0.0
# 1                      32.17    FL                0.5          0.0
# 2                      34.11    NH                0.5          0.0
# 3                      24.61    PA                0.5          0.0
# 4                       0.64    AZ                0.5          0.0
# ...                      ...   ...                ...          ...
# 224895               1361.51    TX                0.5          0.0
# 224896                 11.94    CA                0.5          0.0
# 224897                 17.42    NV                0.5          0.0
# 224898                 86.52    CA                0.5          0.0
# 224899                 12.24    WA                0.5          0.0
#
# [224900 rows x 8 columns]

# %%
loc_df = rej_df.loc[rej_df["State"] == "TX"]

tx_g = loc_df.groupby("Amount Requested", as_index=False).max()
tx_g.groupby("")
# Out:
#      Amount Requested Application Date          Loan Title  Risk_Score  \
# 0               500.0       2007-12-12            lberry26       377.0
# 1              1000.0       2018-12-31            vacation       954.0
# 2              1050.0       2017-04-29  DEBT_CONSOLIDATION       533.0
# 3              1100.0       2018-10-10               other       674.0
# 4              1125.0       2018-01-09               other       657.0
# ..                ...              ...                 ...         ...
# 635           51075.0       2017-10-13                AUTO       661.0
# 636           53325.0       2017-07-28                AUTO       650.0
# 637           54050.0       2017-03-05                AUTO       803.0
# 638           55050.0       2017-11-02                AUTO       680.0
# 639           57025.0       2017-10-12                AUTO       695.0
#
#      Debt-To-Income Ratio State  Employment Length  Policy Code
# 0                   32.17    TX                0.5          0.0
# 1               199998.00    TX               10.0          2.0
# 2                    0.15    TX                0.5          0.0
# 3                  208.33    TX               10.0          0.0
# 4                    2.22    TX                0.5          0.0
# ..                    ...   ...                ...          ...
# 635                100.00    TX                0.5          0.0
# 636                100.00    TX                0.5          0.0
# 637                100.00    TX                0.5          0.0
# 638                100.00    TX                0.5          0.0
# 639                100.00    TX                0.5          0.0
#
# [640 rows x 8 columns]

# %%
# Out:
# AUTO                         312
# DEBT_CONSOLIDATION           116
# other                         66
# CC                            52
# vacation                      28
# MAJOR_PURCHASE                15
# IMPROVEMENT                   12
# MEDICAL                       10
# HOME                           9
# renewable_energy               4
# No Response                    3
# xmas                           1
# surgery                        1
# lberry26                       1
# pasteur                        1
# subway2011                     1
# texas wood floors              1
# BUSINESS                       1
# single mommy                   1
# second transportation          1
# INVESTMENT                     1
# want to get things right       1
# lesson learned in finance      1
# work                           1
# Name: Loan Title, dtype: int64

# %%
g_df1 = rej_df.groupby("State", as_index=False).mean()
# Out:
#    State  Amount Requested  Risk_Score  Debt-To-Income Ratio  \
# 0     AK      14257.821782  622.885149            666.621723
# 1     AL      11440.939137  621.216513            112.378588
# 2     AR      12166.690781  620.704837            131.002456
# 3     AZ      12591.855109  627.932370            138.490972
# 4     CA      13072.210086  634.289714            150.718493
# 5     CO      13412.346004  639.093507            203.087750
# 6     CT      13282.778394  627.102479            153.222560
# 7     DC      12550.348837  610.632558            258.806744
# 8     DE      11642.766667  619.388000             95.547253
# 9     FL      12556.530758  628.413162            176.279228
# 10    GA      12215.757352  621.511184            263.067124
# 11    HI      14874.359444  638.207906            251.669078
# 12    IA       1471.428571  569.571429             13.540000
# 13    ID      13138.076923  641.694231             58.565519
# 14    IL      13036.100983  626.627261            169.499092
# 15    IN      11933.490093  625.956358            116.887655
# 16    KS      12481.672643  625.321209             75.623535
# 17    KY      11821.131261  618.642832            130.252276
# 18    LA      11760.335974  618.061326            177.797236
# 19    MA      12772.016461  633.767165            217.836182
# 20    MD      12399.906909  622.176045            110.803819
# 21    ME      13512.602881  634.351852             69.089609
# 22    MI      12494.046839  624.589256            191.983562
# 23    MN      13093.120805  632.991169             60.733935
# 24    MO      11827.714393  622.156720             96.499092
# 25    MS      11355.171490  619.906752             97.976452
# 26    MT      14143.934426  630.800000            525.587213
# 27    NC      12088.865754  620.551101            103.878147
# 28    ND      13880.414013  639.471338             36.988726
# 29    NE      12438.934426  638.157973            106.535633
# 30    NH      14212.035011  637.258206            409.612363
# 31    NJ      13695.626054  631.432406            182.289913
# 32    NM      12356.122833  631.069329            244.477023
# 33    NV      12496.643519  630.330247             99.907064
# 34    NY      13274.523202  629.137208            127.535475
# 35    OH      11695.054382  620.508314            275.382114
# 36    OK      12734.142259  624.744770            132.979042
# 37    OR      13144.658314  631.305239            238.925490
# 38    PA      12634.512335  625.550086            161.327751
# 39    RI      13120.927802  631.548491            164.182015
# 40    SC      11537.835899  620.797809           1269.859103
# 41    SD      12713.811881  635.043564            448.614990
# 42    TN      11537.907848  624.550926            157.940928
# 43    TX      12707.661897  627.460852            188.696960
# 44    UT      12951.780822  631.817808            167.906171
# 45    VA      12448.363167  621.666505            311.016547
# 46    VT      14270.641646  640.924939             59.636320
# 47    WA      13793.298999  633.887967            252.888472
# 48    WI      11966.374122  623.017051             40.214467
# 49    WV      13256.562500  622.331250            153.650113
# 50    WY      13788.979118  631.401392             33.481949
#
#     Employment Length  Policy Code
# 0            0.908911     0.003960
# 1            0.983412     0.002494
# 2            0.923109     0.002480
# 3            0.960322     0.004188
# 4            1.066175     0.004369
# 5            1.022752     0.003885
# 6            1.057529     0.000740
# 7            0.854651     0.004651
# 8            0.900000     0.002667
# 9            0.980916     0.002632
# 10           0.933405     0.001590
# 11           1.043924     0.004392
# 12           0.928571     0.000000
# 13           0.750962     0.000000
# 14           0.994902     0.001699
# 15           0.904314     0.003511
# 16           0.970287     0.004098
# 17           0.967876     0.002763
# 18           0.962148     0.001761
# 19           1.001949     0.001300
# 20           0.975796     0.003724
# 21           0.984568     0.004115
# 22           1.000491     0.005568
# 23           0.968209     0.001413
# 24           0.921389     0.004012
# 25           0.851554     0.003215
# 26           0.967213     0.000000
# 27           0.896386     0.004800
# 28           0.871019     0.006369
# 29           0.774963     0.008942
# 30           1.071116     0.006565
# 31           1.069632     0.003654
# 32           0.859457     0.004521
# 33           0.963349     0.006173
# 34           1.047346     0.003766
# 35           0.937055     0.003750
# 36           0.880753     0.004184
# 37           0.944191     0.002733
# 38           0.981297     0.002524
# 39           1.081358     0.002155
# 40           0.922906     0.003652
# 41           0.988119     0.000000
# 42           0.922729     0.003527
# 43           0.954314     0.004736
# 44           0.943836     0.005479
# 45           0.931785     0.001935
# 46           1.101695     0.009685
# 47           0.958262     0.001953
# 48           0.950017     0.004012
# 49           0.973750     0.000000
# 50           0.892111     0.000000

# %%
sns.heatmap(rej_df.corr());

# plt.bar()

# %%
g_df = rej_df.groupby("Application Date", as_index = False).mean()

g_df
# Out:
#      Application Date  Amount Requested  Risk_Score  Debt-To-Income Ratio  \
# 0          2007-05-31      12500.000000  578.000000             31.820000
# 1          2007-06-02       5000.000000    0.000000              0.000000
# 2          2007-06-11       4000.000000  628.000000              6.360000
# 3          2007-06-14       4000.000000  640.000000             48.600000
# 4          2007-06-17       2000.000000  628.000000             10.450000
# ...               ...               ...         ...                   ...
# 3948       2018-12-27      10295.454545  598.954545             23.398636
# 3949       2018-12-28      13065.217391  627.260870             38.111739
# 3950       2018-12-29       6464.285714  630.071429             38.040000
# 3951       2018-12-30       9045.454545  645.000000             25.090000
# 3952       2018-12-31       8175.000000  643.900000             54.023000
#
#       Employment Length  Policy Code
# 0              9.000000          0.0
# 1              1.000000          0.0
# 2              0.500000          0.0
# 3              4.000000          0.0
# 4              1.000000          0.0
# ...                 ...          ...
# 3948           1.136364          0.0
# 3949           1.130435          0.0
# 3950           0.535714          0.0
# 3951           0.500000          0.0
# 3952           0.950000          0.0
#
# [3953 rows x 6 columns]

# %%
x = g_df["Amount Requested"]
y = g_df["Risk_Score"]

plt.scatter(x,y)

# %%
hist = rej_df["Amount Requested"]
plt.hist(hist)
# Out:
# (array([9.7519e+04, 6.1154e+04, 2.4957e+04, 2.0518e+04, 1.3449e+04,
#         7.2450e+03, 3.7000e+01, 1.2000e+01, 5.0000e+00, 4.0000e+00]),
#  array([  500.,  7950., 15400., 22850., 30300., 37750., 45200., 52650.,
#         60100., 67550., 75000.]),
#  <BarContainer object of 10 artists>)

# %%
hist1 = rej_df["Risk_Score"]

plt.hist(hist1)
# Out:
# (array([2.19500e+03, 0.00000e+00, 0.00000e+00, 6.70000e+01, 2.00300e+03,
#         5.45250e+04, 1.29888e+05, 3.36160e+04, 2.40900e+03, 1.97000e+02]),
#  array([  0.,  99., 198., 297., 396., 495., 594., 693., 792., 891., 990.]),
#  <BarContainer object of 10 artists>)

# %%
hist2 = rej_df["Debt-To-Income Ratio"]

plt.hist(hist2)
# Out:
# (array([2.24896e+05, 2.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 1.00000e+00]),
#  array([-1.0000000e+00,  4.4087910e+05,  8.8175920e+05,  1.3226393e+06,
#          1.7635194e+06,  2.2043995e+06,  2.6452796e+06,  3.0861597e+06,
#          3.5270398e+06,  3.9679199e+06,  4.4088000e+06]),
#  <BarContainer object of 10 artists>)

# %%
nan_sum = rej_df["Debt-To-Income Ratio"].value_counts()

nan_sum
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#     print(nan_sum)
# Out:
#  0.00       10760
#  100.00      4009
#  9999.00      493
# -1.00         364
#  1.20         282
#             ...
#  249.55         1
#  106.14         1
#  121.60         1
#  138.63         1
#  86.52          1
# Name: Debt-To-Income Ratio, Length: 14864, dtype: int64

# %%
hist3 = rej_df["Policy Code"]

plt.hist(hist3)
# Out:
# (array([224511.,      0.,      0.,      0.,      0.,      0.,      0.,
#              0.,      0.,    389.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
hist4 = rej_df["Employment Length"]

plt.hist(hist4)
# Out:
# (array([206148.,   1936.,   1666.,   1309.,   5663.,    891.,    767.,
#            665.,    517.,   5338.]),
#  array([ 0.5 ,  1.45,  2.4 ,  3.35,  4.3 ,  5.25,  6.2 ,  7.15,  8.1 ,
#          9.05, 10.  ]),
#  <BarContainer object of 10 artists>)

# %%
rej_df["Employment Length"].value_counts()
# Out:
# 0.5     204217
# 5.0       5663
# 10.0      5338
# 2.0       1936
# 1.0       1931
# 3.0       1666
# 4.0       1309
# 6.0        891
# 7.0        767
# 8.0        665
# 9.0        517
# Name: Employment Length, dtype: int64

# %%
rej_df.columns
# Out:
# Index(['Amount Requested', 'Application Date', 'Loan Title', 'Risk_Score',
#        'Debt-To-Income Ratio', 'State', 'Employment Length', 'Policy Code'],
#       dtype='object')

# %%
hist5 = rej_df["Employment Length"]

plt.hist(hist5)
# Out:
# (array([206148.,   1936.,   1666.,   1309.,   5663.,    891.,    767.,
#            665.,    517.,   5338.]),
#  array([ 0.5 ,  1.45,  2.4 ,  3.35,  4.3 ,  5.25,  6.2 ,  7.15,  8.1 ,
#          9.05, 10.  ]),
#  <BarContainer object of 10 artists>)
