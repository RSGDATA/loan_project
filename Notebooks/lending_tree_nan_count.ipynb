# %%
import pandas as pd
from pprint import pprint

# %%
lending_tree_df = pd.read_csv("Resources/lending_club_accepted.csv")



# column_names = lending_tree_df.columns
# for column in lending_tree_df.columns:
#     print(column)
# count = [0]
# column_list =  []   

    
#   column_list.append(column_names)

# lending_tree_df.columns
# column_count = 0

# nan_count = 0
# for column in nan_sum:

#         print(column)

for ind in lending_tree_df.index:
    print(lending_tree_df['loan_amnt'][ind], lending_tree_df['term'][ind])
# Out:
# 32000.0  60 months
# 9600.0  36 months
# 4000.0  36 months
# 6025.0  36 months
# 25000.0  60 months
# 20000.0  36 months
# 1000.0  36 months
# 24575.0  60 months
# 7000.0  36 months
# 16000.0  36 months
# 18000.0  60 months
# 10000.0  36 months
# 16000.0  60 months
# 34975.0  60 months
# 16000.0  36 months
# 7900.0  36 months
# 12000.0  36 months
# 20000.0  60 months
# 12000.0  60 months
# 9350.0  36 months
# 24000.0  36 months
# 8000.0  36 months
# 35000.0  60 months
# 12375.0  60 months
# 3600.0  36 months
# 10000.0  60 months
# 6000.0  36 months
# 8000.0  36 months
# 20800.0  36 months
# 25000.0  60 months
# 6000.0  36 months
# 10000.0  36 months
# 18000.0  60 months
# 4000.0  36 months
# 35000.0  60 months
# 25000.0  36 months
# 4000.0  36 months
# 6000.0  36 months
# 3925.0  36 months
# 15000.0  36 months
# 8000.0  36 months
# 4000.0  36 months
# 14500.0  36 months
# 40000.0  60 months
# 20000.0  36 months
# 21000.0  36 months
# 10500.0  60 months
# 28000.0  36 months
# ...

# %% [markdown]
# ## Drop na
#
# when dropping na 30 rows remain. it is nessesary to find which rows have the most nas and drop the columns before modeling.

# %%
lending_tree_df.dropna()
# Out:
#        loan_amnt        term  int_rate  installment emp_length home_ownership  \
# 2871     24000.0   60 months     16.91       595.31   < 1 year       MORTGAGE
# 3963     30000.0   60 months     24.84       877.73    6 years           RENT
# 4137     13000.0   36 months     17.99       469.92    7 years           RENT
# 11269     9600.0   36 months     10.56       312.30    4 years       MORTGAGE
# 11632     7000.0   36 months      7.97       219.26    7 years       MORTGAGE
# 12688    20000.0   60 months     14.47       470.26  10+ years       MORTGAGE
# 13739    32000.0   36 months     20.39      1195.61  10+ years       MORTGAGE
# 13878    12000.0   36 months      9.44       384.06  10+ years       MORTGAGE
# 14312    25000.0   60 months     13.58       576.28   < 1 year           RENT
# 15665     9600.0   36 months     11.49       316.53    9 years       MORTGAGE
# 18734     6000.0   36 months     11.55       198.00  10+ years       MORTGAGE
# ...

# %% [markdown]
# ## First Step is to find the sum of na by each column

# %%
nan_sum = lending_tree_df.isna().sum()


with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(nan_sum)
# Out:
# loan_amnt                             3
# term                                  3
# int_rate                              3
# installment                           3
# emp_length                         3594
# home_ownership                        3
# annual_inc                            3
# verification_status                   3
# loan_status                           3
# pymnt_plan                            3
# purpose                               3
# title                               559
# zip_code                              3
# addr_state                            3
# dti                                  46
# delinq_2yrs                           3
# fico_range_low                        3
# fico_range_high                       3
# inq_last_6mths                        3
# mths_since_last_delinq            29034
# mths_since_last_record            47331
# open_acc                              3
# pub_rec                               3
# ...

# %% [markdown]
# ## checking to see id nan_sum is counting the ammount of nan in each row

# %%
lending_tree_df['loan_amnt'].isna().sum()
# Out:
# 3

# %% [markdown]
# ## Now make new dataframe based on the count of na in each column

# %%
nan_df = pd.DataFrame({
                    "nan count by name": nan_sum
})

nan_df
# Out:
#                             nan count by name
# loan_amnt                                   3
# term                                        3
# int_rate                                    3
# installment                                 3
# emp_length                               3594
# ...                                       ...
# tot_hi_cred_lim                          1710
# total_bal_ex_mort                        1220
# total_bc_limit                           1220
# total_il_high_credit_limit               1710
# disbursement_method                         3
#
# [100 rows x 1 columns]

# %%
nan_df.to_csv("nan_count_by_column.csv")

# %%
lending_tree_df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'emp_length',
#        'home_ownership', 'annual_inc', 'verification_status', 'loan_status',
#        'pymnt_plan', 'purpose', 'title', 'zip_code', 'addr_state', 'dti',
#        'delinq_2yrs', 'fico_range_low', 'fico_range_high', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'last_fico_range_high', 'last_fico_range_low',
#        'collections_12_mths_ex_med', 'mths_since_last_major_derog',
#        'policy_code', 'application_type', 'verification_status_joint',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
# ...

# %% [markdown]
# ## Dropping the columns with the most nas

# %%
lending_tree_df1 = lending_tree_df.drop(["mths_since_last_record",
                      "mths_since_last_delinq",
                      "mths_since_last_major_derog",
                      "verification_status_joint",
                      "mths_since_recent_bc_dlq",
                      "mths_since_recent_revol_delinq"], axis=1)

# %% [markdown]
# ## When dropna on dataframe now 23290 rows and 94 columns remain

# %%
clean_lending_tree_df = lending_tree_df1.dropna()

clean_lending_tree_df
# Out:
#        loan_amnt        term  int_rate  installment emp_length home_ownership  \
# 3         6025.0   36 months     10.91       197.00  10+ years           RENT
# 4        25000.0   60 months     26.30       752.96  10+ years            OWN
# 5        20000.0   36 months      9.49       640.57  10+ years       MORTGAGE
# 7        24575.0   60 months     14.49       578.08    5 years           RENT
# 8         7000.0   36 months      6.99       216.11    5 years           RENT
# ...          ...         ...       ...          ...        ...            ...
# 56510     4000.0   36 months     15.02       138.71  10+ years            OWN
# 56511     2200.0   36 months      7.21        68.15    9 years       MORTGAGE
# 56513    21000.0   36 months     22.91       811.92    2 years            OWN
# 56516    28750.0   60 months     18.99       745.64    7 years            OWN
# 56517    10000.0   36 months      7.21       309.74    9 years       MORTGAGE
#
# ...

# %%
clean_lending_tree_df.to_csv("dropna_lending_tree.csv")
