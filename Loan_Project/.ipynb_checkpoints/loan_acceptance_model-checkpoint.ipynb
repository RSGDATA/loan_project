# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
loan_df = pd.read_csv("Loan_Default.csv")

loan_df.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 1           p1                l1        nopc                    b/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
#
#    credit_type  Credit_Score  co-applicant_credit_type    age  \
# 0          EXP           758                       CIB  25-34
# 1         EQUI           552                       EXP  55-64
# 2          EXP           834                       CIB  35-44
# 3          EXP           587                       CIB  45-54
# 4         CRIF           602                       EXP  25-34
#
#    submission_of_application Loan_To_Value_Ratio Region Security_Type  Status  \
# 0                    to_inst           98.728814  south        direct       1
# 1                    to_inst                 NaN  North        direct       1
# 2                    to_inst           80.019685  south        direct       0
# 3                   not_inst           69.376900  North        direct       0
# 4                   not_inst           91.886544  North        direct       0
#
#   debt_to_income_ratio
# 0                 45.0
# 1                  NaN
# 2                 46.0
# 3                 42.0
# 4                 39.0
#
# [5 rows x 34 columns]

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
#  13  Upfront_charges            109028 non-null  float64
#  14  term                       148629 non-null  float64
#  15  Neg_ammortization          148549 non-null  object
#  16  interest_only              148670 non-null  object
#  17  lump_sum_payment           148670 non-null  object
#  18  property_value             133572 non-null  float64
#  19  construction_type          148670 non-null  object
#  20  occupancy_type             148670 non-null  object
#  21  Secured_by                 148670 non-null  object
#  22  total_units                148670 non-null  object
#  23  income                     139520 non-null  float64
#  24  credit_type                148670 non-null  object
#  25  Credit_Score               148670 non-null  int64
#  26  co-applicant_credit_type   148670 non-null  object
#  27  age                        148470 non-null  object
#  28  submission_of_application  148470 non-null  object
#  29  Loan_To_Value_Ratio        133572 non-null  float64
#  30  Region                     148670 non-null  object
#  31  Security_Type              148670 non-null  object
#  32  Status                     148670 non-null  int64
#  33  debt_to_income_ratio       124549 non-null  float64
# dtypes: float64(8), int64(5), object(21)
# memory usage: 38.6+ MB

# %%
loan_df1 = loan_df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# 25%                0.076000       581.490000     360.000000    2.680000e+05
# 50%                0.390400      2596.450000     360.000000    4.180000e+05
# 75%                0.775400      4812.500000     360.000000    6.280000e+05
# max                3.357000     60000.000000     360.000000    1.650800e+07
#
#               income   Credit_Score  Loan_To_Value_Ratio         Status  \
# count  139520.000000  148670.000000        133572.000000  148670.000000
# mean     6957.338876     699.789103            72.746457       0.246445
# std      6496.586382     115.875857            39.967603       0.430942
# min         0.000000     500.000000             0.967478       0.000000
# 25%      3720.000000     599.000000            60.474860       0.000000
# 50%      5760.000000     699.000000            75.135870       0.000000
# 75%      8520.000000     800.000000            86.184211       0.000000
# max    578580.000000     900.000000          7831.250000       1.000000
#
#        debt_to_income_ratio
# count         124549.000000
# mean              37.732932
# std               10.545435
# min                5.000000
# 25%               31.000000
# 50%               39.000000
# 75%               45.000000
# max               61.000000

# %%
loan_df2 = loan_df.groupby("Credit_Score", as_index=False).mean()
loan_df2
# Out:
#      Credit_Score             ID    year    loan_amount  rate_of_interest  \
# 0             500  101677.803922  2019.0  316051.820728          4.018691
# 1             501  100366.218487  2019.0  324819.327731          4.113822
# 2             502   99867.225434  2019.0  323985.549133          4.073479
# 3             503  100480.101828  2019.0  335272.845953          4.044441
# 4             504   99443.918367  2019.0  320938.775510          4.069933
# ..            ...            ...     ...            ...               ...
# 396           896   96890.938619  2019.0  340796.675192          4.032247
# 397           897  101467.650131  2019.0  333836.814621          4.008596
# 398           898  103106.575676  2019.0  323635.135135          4.049113
# 399           899   97984.312500  2019.0  324596.590909          4.013032
# 400           900  101231.323155  2019.0  327619.592875          4.075160
#
#      Interest_rate_spread  Upfront_charges        term  property_value  \
# 0                0.409251      3371.573293  334.588235   483968.253968
# 1                0.521643      3110.354160  335.798319   463590.062112
# 2                0.445933      3020.502421  341.861272   510770.700637
# 3                0.475106      3460.761510  332.365535   490193.732194
# 4                0.451830      3096.572062  336.673469   487521.126761
# ..                    ...              ...         ...             ...
# 396              0.470630      3372.593979  333.667519   526296.089385
# 397              0.437119      3379.223649  328.073107   490611.275964
# 398              0.437682      3272.655884  341.383784   505619.047619
# 399              0.434812      3301.268996  331.840909   496190.789474
# 400              0.497551      2743.682410  336.244275   485127.071823
#
#           income  Loan_To_Value_Ratio    Status  debt_to_income_ratio
# 0    6780.887574            72.022276  0.282913             39.030405
# 1    6625.820433            74.650849  0.280112             37.857639
# 2    6615.789474            71.536367  0.239884             38.240550
# 3    7436.000000            72.730580  0.206266             37.597561
# 4    6714.545455            72.289335  0.242347             36.926829
# ..           ...                  ...       ...                   ...
# 396  7468.702703            72.181899  0.242967             38.086053
# 397  6411.428571            73.303909  0.237598             37.874214
# 398  7055.384615            72.543366  0.237838             38.041009
# 399  6679.819820            71.941627  0.292614             38.740351
# 400  6640.271739            73.161475  0.287532             38.732938
#
# [401 rows x 13 columns]

# %%
numeric
# Out:
# 148670

# %%
x = loan_df2["Status"]
y = loan_df2["debt_to_income_ratio"]

plt.scatter(x,y)
plt.show()

# %%
x = loan_df2["income"]
y = loan_df2["Status"]

plt.scatter(x,y)
plt.show()

# %%
x = loan_df2["income"]
y = loan_df2["Credit_Score"]

plt.scatter(x,y)
plt.show()

# %%
clean_loan_df = loan_df.dropna()

clean_loan_df
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 2        24892  2019         cf               Male           pre     type1
# 4        24894  2019         cf              Joint           pre     type1
# 5        24895  2019         cf              Joint           pre     type1
# 6        24896  2019         cf              Joint           pre     type1
# 8        24898  2019         cf              Joint         nopre     type1
# ...        ...   ...        ...                ...           ...       ...
# 148665  173555  2019         cf  Sex Not Available         nopre     type1
# 148666  173556  2019         cf               Male         nopre     type1
# 148667  173557  2019         cf               Male         nopre     type1
# 148668  173558  2019         cf             Female         nopre     type1
# 148669  173559  2019         cf             Female         nopre     type1
#
#        loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 2                p1                l1        nopc                  nob/c  ...
# 4                p1                l1        nopc                  nob/c  ...
# 5                p1                l1        nopc                  nob/c  ...
# 6                p3                l1        nopc                  nob/c  ...
# 8                p3                l1        nopc                  nob/c  ...
# ...             ...               ...         ...                    ...  ...
# 148665           p3                l1        nopc                  nob/c  ...
# 148666           p1                l1        nopc                  nob/c  ...
# 148667           p4                l1        nopc                  nob/c  ...
# 148668           p4                l1        nopc                  nob/c  ...
# 148669           p3                l1        nopc                  nob/c  ...
#
#         credit_type  Credit_Score  co-applicant_credit_type    age  \
# 2               EXP           834                       CIB  35-44
# 4              CRIF           602                       EXP  25-34
# 5               EXP           864                       EXP  35-44
# 6               EXP           860                       EXP  55-64
# 8               CIB           580                       EXP  55-64
# ...             ...           ...                       ...    ...
# 148665          CIB           659                       EXP  55-64
# 148666          CIB           569                       CIB  25-34
# 148667          CIB           702                       EXP  45-54
# 148668          EXP           737                       EXP  55-64
# 148669          CIB           830                       CIB  45-54
#
#         submission_of_application Loan_To_Value_Ratio   Region Security_Type  \
# 2                         to_inst           80.019685    south        direct
# 4                        not_inst           91.886544    North        direct
# 5                        not_inst           70.089286    North        direct
# 6                         to_inst           79.109589    North        direct
# 8                         to_inst           78.765690  central        direct
# ...                           ...                 ...      ...           ...
# 148665                    to_inst           71.792763    south        direct
# 148666                   not_inst           74.428934    south        direct
# 148667                   not_inst           61.332418    North        direct
# 148668                    to_inst           70.683453    North        direct
# 148669                   not_inst           72.849462    North        direct
#
#         Status debt_to_income_ratio
# 2            0                 46.0
# 4            0                 39.0
# 5            0                 40.0
# 6            0                 44.0
# 8            0                 44.0
# ...        ...                  ...
# 148665       0                 48.0
# 148666       0                 15.0
# 148667       0                 49.0
# 148668       0                 29.0
# 148669       0                 44.0
#
# [98187 rows x 34 columns]

# %%
# numeric_loan_df = pd.get_dummies(clean_loan_df)

numeric_loan_df = clean_loan_df.apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "cf"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_15291/2885368690.py in <module>
#       1 # numeric_loan_df = pd.get_dummies(clean_loan_df)
#       2
# ----> 3 numeric_loan_df = clean_loan_df.apply(pd.to_numeric)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     181         coerce_numeric = errors not in ("ignore", "raise")
#     182         try:
# --> 183             values, _ = lib.maybe_convert_numeric(
#     184                 values, set(), coerce_numeric=coerce_numeric
#     185             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "cf" at position 0

# %%
numeric_loan_df["Credit_Score"].nunique()
# Out:
# 401

# %%
for (columnName, columnData) in numeric_loan_df.iteritems():
   print('Colunm Name : ', columnName)
   print('Column Contents : ', columnData.nunique)
# Out:
# Colunm Name :  ID
# Column Contents :  <bound method IndexOpsMixin.nunique of 2          24892
# 4          24894
# 5          24895
# 6          24896
# 8          24898
#            ...
# 148665    173555
# 148666    173556
# 148667    173557
# 148668    173558
# 148669    173559
# Name: ID, Length: 98187, dtype: int64>
# Colunm Name :  year
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         2019
# 4         2019
# 5         2019
# 6         2019
# 8         2019
#           ...
# 148665    2019
# 148666    2019
# 148667    2019
# 148668    2019
# 148669    2019
# Name: year, Length: 98187, dtype: int64>
# Colunm Name :  loan_amount
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         406500
# 4         696500
# 5         706500
# 6         346500
# 8         376500
#            ...
# 148665    436500
# 148666    586500
# 148667    446500
# 148668    196500
# 148669    406500
# Name: loan_amount, Length: 98187, dtype: int64>
# Colunm Name :  rate_of_interest
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         4.560
# 4         4.000
# 5         3.990
# 6         4.500
# 8         4.875
#           ...
# 148665    3.125
# 148666    5.190
# 148667    3.125
# 148668    3.500
# 148669    4.375
# Name: rate_of_interest, Length: 98187, dtype: float64>
# Colunm Name :  Interest_rate_spread
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0.2000
# 4         0.3042
# 5         0.1523
# 6         0.9998
# 8         0.7395
#            ...
# 148665    0.2571
# 148666    0.8544
# 148667    0.0816
# 148668    0.5824
# 148669    1.3871
# Name: Interest_rate_spread, Length: 98187, dtype: float64>
# Colunm Name :  Upfront_charges
# Column Contents :  <bound method IndexOpsMixin.nunique of 2          595.00
# 4            0.00
# 5          370.00
# 6         5120.00
# 8         1150.00
#            ...
# 148665    9960.00
# 148666       0.00
# 148667    1226.64
# 148668    4323.33
# 148669    6000.00
# Name: Upfront_charges, Length: 98187, dtype: float64>
# Colunm Name :  term
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         360.0
# 4         360.0
# 5         360.0
# 6         360.0
# 8         360.0
#           ...
# 148665    180.0
# 148666    360.0
# 148667    180.0
# 148668    180.0
# 148669    240.0
# Name: term, Length: 98187, dtype: float64>
# Colunm Name :  property_value
# Column Contents :  <bound method IndexOpsMixin.nunique of 2          508000.0
# 4          758000.0
# 5         1008000.0
# 6          438000.0
# 8          478000.0
#             ...
# 148665     608000.0
# 148666     788000.0
# 148667     728000.0
# 148668     278000.0
# 148669     558000.0
# Name: property_value, Length: 98187, dtype: float64>
# Colunm Name :  income
# Column Contents :  <bound method IndexOpsMixin.nunique of 2          9480.0
# 4         10440.0
# 5         10080.0
# 6          5040.0
# 8          5580.0
#            ...
# 148665     7860.0
# 148666     7140.0
# 148667     6900.0
# 148668     7140.0
# 148669     7260.0
# Name: income, Length: 98187, dtype: float64>
# Colunm Name :  Credit_Score
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         834
# 4         602
# 5         864
# 6         860
# 8         580
#          ...
# 148665    659
# 148666    569
# 148667    702
# 148668    737
# 148669    830
# Name: Credit_Score, Length: 98187, dtype: int64>
# Colunm Name :  Loan_To_Value_Ratio
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         80.019685
# 4         91.886544
# 5         70.089286
# 6         79.109589
# 8         78.765690
#             ...
# 148665    71.792763
# 148666    74.428934
# 148667    61.332418
# 148668    70.683453
# 148669    72.849462
# Name: Loan_To_Value_Ratio, Length: 98187, dtype: float64>
# Colunm Name :  Status
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Status, Length: 98187, dtype: int64>
# Colunm Name :  debt_to_income_ratio
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         46.0
# 4         39.0
# 5         40.0
# 6         44.0
# 8         44.0
#           ...
# 148665    48.0
# 148666    15.0
# 148667    49.0
# 148668    29.0
# 148669    44.0
# Name: debt_to_income_ratio, Length: 98187, dtype: float64>
# Colunm Name :  loan_limit_cf
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: loan_limit_cf, Length: 98187, dtype: uint8>
# Colunm Name :  loan_limit_ncf
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: loan_limit_ncf, Length: 98187, dtype: uint8>
# Colunm Name :  Gender_Female
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    1
# 148669    1
# Name: Gender_Female, Length: 98187, dtype: uint8>
# Colunm Name :  Gender_Joint
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Gender_Joint, Length: 98187, dtype: uint8>
# Colunm Name :  Gender_Male
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    1
# 148667    1
# 148668    0
# 148669    0
# Name: Gender_Male, Length: 98187, dtype: uint8>
# Colunm Name :  Gender_Sex Not Available
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    1
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Gender_Sex Not Available, Length: 98187, dtype: uint8>
# Colunm Name :  approv_in_adv_nopre
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: approv_in_adv_nopre, Length: 98187, dtype: uint8>
# Colunm Name :  approv_in_adv_pre
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: approv_in_adv_pre, Length: 98187, dtype: uint8>
# Colunm Name :  loan_type_type1
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: loan_type_type1, Length: 98187, dtype: uint8>
# Colunm Name :  loan_type_type2
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: loan_type_type2, Length: 98187, dtype: uint8>
# Colunm Name :  loan_type_type3
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: loan_type_type3, Length: 98187, dtype: uint8>
# Colunm Name :  loan_purpose_p1
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    1
# 148667    0
# 148668    0
# 148669    0
# Name: loan_purpose_p1, Length: 98187, dtype: uint8>
# Colunm Name :  loan_purpose_p2
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: loan_purpose_p2, Length: 98187, dtype: uint8>
# Colunm Name :  loan_purpose_p3
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    0
# 148667    0
# 148668    0
# 148669    1
# Name: loan_purpose_p3, Length: 98187, dtype: uint8>
# Colunm Name :  loan_purpose_p4
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    1
# 148668    1
# 148669    0
# Name: loan_purpose_p4, Length: 98187, dtype: uint8>
# Colunm Name :  Credit_Worthiness_l1
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: Credit_Worthiness_l1, Length: 98187, dtype: uint8>
# Colunm Name :  Credit_Worthiness_l2
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Credit_Worthiness_l2, Length: 98187, dtype: uint8>
# Colunm Name :  open_credit_nopc
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: open_credit_nopc, Length: 98187, dtype: uint8>
# Colunm Name :  business_or_commercial_b/c
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: business_or_commercial_b/c, Length: 98187, dtype: uint8>
# Colunm Name :  business_or_commercial_nob/c
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: business_or_commercial_nob/c, Length: 98187, dtype: uint8>
# Colunm Name :  Neg_ammortization_neg_amm
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Neg_ammortization_neg_amm, Length: 98187, dtype: uint8>
# Colunm Name :  Neg_ammortization_not_neg
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: Neg_ammortization_not_neg, Length: 98187, dtype: uint8>
# Colunm Name :  interest_only_int_only
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: interest_only_int_only, Length: 98187, dtype: uint8>
# Colunm Name :  interest_only_not_int
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: interest_only_not_int, Length: 98187, dtype: uint8>
# Colunm Name :  lump_sum_payment_lpsm
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: lump_sum_payment_lpsm, Length: 98187, dtype: uint8>
# Colunm Name :  lump_sum_payment_not_lpsm
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: lump_sum_payment_not_lpsm, Length: 98187, dtype: uint8>
# Colunm Name :  construction_type_sb
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: construction_type_sb, Length: 98187, dtype: uint8>
# Colunm Name :  occupancy_type_ir
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    1
# 148667    0
# 148668    0
# 148669    0
# Name: occupancy_type_ir, Length: 98187, dtype: uint8>
# Colunm Name :  occupancy_type_pr
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    0
# 148667    1
# 148668    1
# 148669    1
# Name: occupancy_type_pr, Length: 98187, dtype: uint8>
# Colunm Name :  occupancy_type_sr
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: occupancy_type_sr, Length: 98187, dtype: uint8>
# Colunm Name :  Secured_by_home
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: Secured_by_home, Length: 98187, dtype: uint8>
# Colunm Name :  total_units_1U
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    0
# 148667    1
# 148668    1
# 148669    1
# Name: total_units_1U, Length: 98187, dtype: uint8>
# Colunm Name :  total_units_2U
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: total_units_2U, Length: 98187, dtype: uint8>
# Colunm Name :  total_units_3U
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: total_units_3U, Length: 98187, dtype: uint8>
# Colunm Name :  total_units_4U
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    1
# 148667    0
# 148668    0
# 148669    0
# Name: total_units_4U, Length: 98187, dtype: uint8>
# Colunm Name :  credit_type_CIB
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    0
# 148669    1
# Name: credit_type_CIB, Length: 98187, dtype: uint8>
# Colunm Name :  credit_type_CRIF
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         1
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: credit_type_CRIF, Length: 98187, dtype: uint8>
# Colunm Name :  credit_type_EQUI
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: credit_type_EQUI, Length: 98187, dtype: uint8>
# Colunm Name :  credit_type_EXP
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         0
# 5         1
# 6         1
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    1
# 148669    0
# Name: credit_type_EXP, Length: 98187, dtype: uint8>
# Colunm Name :  co-applicant_credit_type_CIB
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    1
# 148667    0
# 148668    0
# 148669    1
# Name: co-applicant_credit_type_CIB, Length: 98187, dtype: uint8>
# Colunm Name :  co-applicant_credit_type_EXP
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    0
# 148667    1
# 148668    1
# 148669    0
# Name: co-applicant_credit_type_EXP, Length: 98187, dtype: uint8>
# Colunm Name :  age_25-34
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         1
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    1
# 148667    0
# 148668    0
# 148669    0
# Name: age_25-34, Length: 98187, dtype: uint8>
# Colunm Name :  age_35-44
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         0
# 5         1
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: age_35-44, Length: 98187, dtype: uint8>
# Colunm Name :  age_45-54
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    1
# 148668    0
# 148669    1
# Name: age_45-54, Length: 98187, dtype: uint8>
# Colunm Name :  age_55-64
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    0
# 148667    0
# 148668    1
# 148669    0
# Name: age_55-64, Length: 98187, dtype: uint8>
# Colunm Name :  age_65-74
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: age_65-74, Length: 98187, dtype: uint8>
# Colunm Name :  age_<25
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: age_<25, Length: 98187, dtype: uint8>
# Colunm Name :  age_>74
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: age_>74, Length: 98187, dtype: uint8>
# Colunm Name :  submission_of_application_not_inst
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         1
# 5         1
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    1
# 148667    1
# 148668    0
# 148669    1
# Name: submission_of_application_not_inst, Length: 98187, dtype: uint8>
# Colunm Name :  submission_of_application_to_inst
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         0
# 5         0
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    0
# 148667    0
# 148668    1
# 148669    0
# Name: submission_of_application_to_inst, Length: 98187, dtype: uint8>
# Colunm Name :  Region_North
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         1
# 5         1
# 6         1
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    1
# 148668    1
# 148669    1
# Name: Region_North, Length: 98187, dtype: uint8>
# Colunm Name :  Region_North-East
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Region_North-East, Length: 98187, dtype: uint8>
# Colunm Name :  Region_central
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         0
# 4         0
# 5         0
# 6         0
# 8         1
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Region_central, Length: 98187, dtype: uint8>
# Colunm Name :  Region_south
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         0
# 5         0
# 6         0
# 8         0
#          ..
# 148665    1
# 148666    1
# 148667    0
# 148668    0
# 148669    0
# Name: Region_south, Length: 98187, dtype: uint8>
# Colunm Name :  Security_Type_direct
# Column Contents :  <bound method IndexOpsMixin.nunique of 2         1
# 4         1
# 5         1
# 6         1
# 8         1
#          ..
# 148665    1
# 148666    1
# 148667    1
# 148668    1
# 148669    1
# Name: Security_Type_direct, Length: 98187, dtype: uint8>

# %%
from sklearn.model_selection import train_test_split
# X = train_df
X = loan_df.drop(["target_high_risk","target_low_risk"], axis=1)

y = loan_df["target_high_risk"]


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)


from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier

classifier.fit(X_train,y_train)

print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_15291/1776222220.py in <module>
#       1 from sklearn.model_selection import train_test_split
#       2 # X = train_df
# ----> 3 X = loan_df.drop(["target_high_risk","target_low_risk"], axis=1)
#       4
#       5 y = loan_df["target_high_risk"]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['target_high_risk' 'target_low_risk'] not found in axis"

# %%
from sklearn.model_selection import train_test_split
# X = train_df
X = numeric_loan_df.drop(["Status"], axis=1)

y = numeric_loan_df["Status"]


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# scaler = StandardScaler().fit(X_train)
# X_train_scaled = scaler.transform(X_train)
# X_test_scaled = scaler.transform(X_test)
# from sklearn.linear_model import LogisticRegression
# classifier = LogisticRegression()
# classifier
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestClassifier

reg = Lasso(max_iter=1000).fit(X_train_scaled, y_train)


# clf = RandomForestClassifier(random_state=42, n_estimators=50).fit(X_train_scaled, y_train)
print(f'Training Score: {reg.score(X_train_scaled, y_train)}')
print(f'Testing Score: {reg.score(X_test_scaled, y_test)}')
# classifier.fit(X_train,y_train)

# print(f"Training Data Score: {classifier.score(X_train, y_train)}")
# print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Score: 1.0
# Testing Score: 1.0
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
#   model = cd_fast.enet_coordinate_descent(

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier

classifier.fit(X_train_scaled,y_train)

print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_15291/2134666952.py in <module>
#       3 classifier
#       4
# ----> 5 classifier.fit(X_train_scaled,y_train)
#       6
#       7 print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1372         classes_ = self.classes_
#    1373         if n_classes < 2:
# -> 1374             raise ValueError("This solver needs samples of at least 2 classes"
#    1375                              " in the data, but the data contains only one"
#    1376                              " class: %r" % classes_[0])
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0

# %%
loan_df.columns
# Out:
# Index(['ID', 'year', 'loan_limit', 'Gender', 'approv_in_adv', 'loan_type',
#        'loan_purpose', 'Credit_Worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'Interest_rate_spread', 'Upfront_charges', 'term', 'Neg_ammortization',
#        'interest_only', 'lump_sum_payment', 'property_value',
#        'construction_type', 'occupancy_type', 'Secured_by', 'total_units',
#        'income', 'credit_type', 'Credit_Score', 'co-applicant_credit_type',
#        'age', 'submission_of_application', 'Loan_To_Value_Ratio', 'Region',
#        'Security_Type', 'Status', 'debt_to_income_ratio'],
#       dtype='object')

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
#  13  Upfront_charges            109028 non-null  float64
#  14  term                       148629 non-null  float64
#  15  Neg_ammortization          148549 non-null  object
#  16  interest_only              148670 non-null  object
#  17  lump_sum_payment           148670 non-null  object
#  18  property_value             133572 non-null  float64
#  19  construction_type          148670 non-null  object
#  20  occupancy_type             148670 non-null  object
#  21  Secured_by                 148670 non-null  object
#  22  total_units                148670 non-null  object
#  23  income                     139520 non-null  float64
#  24  credit_type                148670 non-null  object
#  25  Credit_Score               148670 non-null  int64
#  26  co-applicant_credit_type   148670 non-null  object
#  27  age                        148470 non-null  object
#  28  submission_of_application  148470 non-null  object
#  29  Loan_To_Value_Ratio        133572 non-null  float64
#  30  Region                     148670 non-null  object
#  31  Security_Type              148670 non-null  object
#  32  Status                     148670 non-null  int64
#  33  debt_to_income_ratio       124549 non-null  float64
# dtypes: float64(8), int64(5), object(21)
# memory usage: 38.6+ MB

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns


sns.set_theme(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)
# d = pd.DataFrame(data=rs.normal(size=(100, 26)),
#                  columns=list(ascii_letters[26:]))

# Compute the correlation matrix
corr = loan_df.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(loan_df.corr());
