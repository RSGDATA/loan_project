# %%
import pandas as pd

# %%
accepted_pd=pd.read_csv("Resources/lending_club_accepted.csv")
accepted_pd
# Out:
# C:\Users\dczor\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       39651438        NaN    32000.0      32000.0          32000.0
# 1       16411620        NaN     9600.0       9600.0           9600.0
# 2       45122316        NaN     4000.0       4000.0           4000.0
# 3      125356772        NaN     6025.0       6025.0           6025.0
# 4      128490686        NaN    25000.0      25000.0          25000.0
# ...          ...        ...        ...          ...              ...
# 56513  121790258        NaN    21000.0      21000.0          20750.0
# 56514     740735        NaN    16000.0      16000.0          16000.0
# 56515    1706365        NaN    18000.0      18000.0          18000.0
# ...

# %%
accepted_pd['Risk_Score']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Risk_Score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
rejected_pd=pd.read_csv("Resources/lending_club_rejected.csv")
rejected_pd
# Out:
#         Amount Requested Application Date               Loan Title  \
# 0                15000.0       2015-10-29       debt_consolidation
# 1                10000.0       2017-10-28  Credit card refinancing
# 2                10000.0       2018-03-09       Debt consolidation
# 3                 7000.0       2016-10-18       Debt consolidation
# 4                 5000.0       2017-02-07                    other
# ...                  ...              ...                      ...
# 691214            4500.0       2016-06-29                    other
# 691215           10000.0       2016-06-06       debt_consolidation
# 691216           20000.0       2016-10-26                    Other
# 691217           15000.0       2018-07-20       Debt consolidation
# 691218           14075.0       2018-03-19            Car financing
#
#         Risk_Score Debt-To-Income Ratio Zip Code State Employment Length  \
# 0              NaN               54.58%    761xx    TX          < 1 year
# ...

# %%
len(rejected_pd)
# Out:
# 691219

# %%
len(accepted_pd)
# Out:
# 56518

# %%
accepted_df
df[df['A'].str.contains("hello")]
