# %%
import pandas as pd

# %%
accepted_df = pd.read_csv("Resources/lending_club_accepted.csv")
accepted_df
# Out:
# /Users/andrealynnbaker/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       39651438        NaN    32000.0      32000.0          32000.0
# 1       16411620        NaN     9600.0       9600.0           9600.0
# 2       45122316        NaN     4000.0       4000.0           4000.0
# 3      125356772        NaN     6025.0       6025.0           6025.0
# 4      128490686        NaN    25000.0      25000.0          25000.0
# ...          ...        ...        ...          ...              ...
# 56513  121790258        NaN    21000.0      21000.0          20750.0
# 56514     740735        NaN    16000.0      16000.0          16000.0
# 56515    1706365        NaN    18000.0      18000.0          18000.0
# ...

# %%
accepted_df.drop(["member_id","hardship_payoff_balance_amount","hardship_last_payment_amount"], axis= 1)

nan = accepted_df.isna().any()

nan.columns()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_26021/1364013549.py in <module>
#       3 nan = accepted_df.isna().any()
#       4
# ----> 5 nan.columns()
#       6
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
sns.heatmap(accepted_df.corr());
